# %% [markdown]
# # 08 PJT

# %% [markdown]
# ## 챕터의 포인트
# - 관통 Ver1. 테스트 & 성능 테스트 개념 (with. Locust)
#     - [실습] 정렬 알고리즘 성능 측정
#
# - 관통 Ver2. 비동기 통신을 이용한 웹사이트 구현
#     - [실습] 업다운 게임 구현

# %% [markdown]
# ## 금융 상품 비교 앱 PJT 08
# ### Django에서 알고리즘 구현 및 성능측정

# %% [markdown]
# ### 목표

# %% [markdown]
# #### 프로젝트 목표
# - 이번 프로젝트에서는 Django 에서 요구사항에 따라 알고리즘을
# 구현해보고 구현한 알고리즘 `성능(시간, 공간)`을 측정합니다.
#
# - Locust 라는 툴을 이용하면 사진과 같이 성능 테스트를 할 수 있습니다.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 진행 순서
# 1. 테스트 & 성능 테스트 개념
#
# 2. Locust 세팅
# 3. 정렬 알고리즘 성능 측정 실습

# %% [markdown]
# ### 테스트

# %% [markdown]
# #### 테스트란?
# - 원하는 기능이 모두 구현되었는 지 확인하고(20%), 숨겨져 있는 결함을 찾는(60%) 활동
#
# - 여러가지 도구들을 활용하여 버그를 찾아내고 `신뢰성`, `보안`, `성능` 등을 검증하는 중요한 단계
# - 테스트의 종류는 너무 많다..!! (100가지가 넘습니다)
# - `상황에 맞게 필요한 테스트를 진행해야 합니다. `
#     - 외우지 말고 검색을 통해 필요한 것만 찾아서 사용해야 합니다.
#
# **필수로 알아야 할 테스트**
# 1. 유닛 테스트
#     - 내가 개발한 개별 함수가 잘 동작하는가?
#
# 2. 회귀 테스트
#     - 기존 있던 코드들은 버그가 없는가?
#
# 3. 통합 테스트
#     - 여러 시스템을 붙였을 때 잘 돌아가는가?

# %% [markdown]
# #### 성능 테스트
# - 핵심 적인 테스트 중 하나
#
# - 특정 상황에서 시스템이 어느 정도 수준을 보이는가 혹은 어떻게 대처를 하는가를 테스트하는 과정
# - 목적
#     - 여러 테스트를 통해 성능 저하가 발생하는 요인을 발견하고 제거
#     - 시장에 출시되기 전에 발생할 수 있는 위험과 개선사항을 파악
#     - 안정적이고 신뢰할 수 있는 제품을 빠르게 만들기 위함

# %% [markdown]
# #### 성능 테스트 예시
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 성능 테스트
# - 성능 테스트의 종류도 많습니다.
#
# - 그 중, 프로젝트에서는 핵심인 `부하 테스트`와 `스트레스 테스트`를 배웁니다.

# %% [markdown]
# #### 부하 테스트 (Load Testing)
# - 시스템에 임계점의 부하가 `계속될 때` 문제가 없는가?
#     - 임계점: 사용자 혹은 요청이 점점 늘어나다가, 응답시간이 급격히 느려지는 시점
#
# - 목적 : 시스템의 신뢰도와 성능을 측정
#
#     ![image.png](attachment:image.png)

# %% [markdown]
# #### 스트레스 테스트 (Stress Testing)
# - 시스템에 과부하가 오면 어떻게 동작할까?
#
# - 목적 : 장애 조치와 복구 절차가 효과적이고 효율적인 지 확인
#
#     ![image.png](attachment:image.png)

# %% [markdown]
# #### 부하 테스트 vs 스트레스 테스트
# ![image.png](attachment:image.png)

# %% [markdown]
# ### API 성능 테스트

# %% [markdown]
# #### Locust
# - `오픈 소스 부하 테스트 도구 `
#
# - 번역하면 메뚜기. 테스트 중 메뚜기 떼가 웹 사이트를 공격한다는 의미로 착안된 이름
# - 내가 만든 서버에 `수많은 사용자들이 동시에 들어올 때 어떤 일이 벌어 지는 지`를 확인하는 부하 테스트를 할 수 있는 도구
# - Locust를 선택한 이유
#     - 파이썬 언어로 테스트 시나리오를 간편하게 작성할 수 있습니다.
#     - 결과를 웹에서 확인할 수 있는 UI를 지원합니다.
#
#     ![image.png](attachment:image.png)

# %% [markdown]
# #### Locust 사용법
# ppt 10장

# %% [markdown]
# ### 정렬 알고리즘 테스트

# %% [markdown]
# #### 테스트 주의사항
# - 오늘 테스트는 정석적인 방법과는 거리가 있습니다.
#     - 정석: 서버에 배포된 API 또는 프로그램에 부하 테스트를 해야 합니다.
#
# - 하지만, 현재는 PC 에서 작동 중인 서버로 요청을 보내는 것
#     - PC 의 성능에 따라 결과가 매우 달라집니다.
#     - 현재 서버가 작동 중인 PC에서 테스트를 진행하므로, 테스트 중 다른 조작을 하지 말아야 합니다!

# %% [markdown]
# #### 정렬 알고리즘 구현하기
# - 대상
#     1. 파이썬 내장 정렬함수 - O(N logN)
#     2. 버블 정렬 - O(n^2)
#     3. 우선순위 큐 - 삽입: O(logN), 삭제: O(logN)
#
# - 시나리오1. 랜덤 배열 크기 1,000 / 랜덤 범위 5,000 의 배열을 만들어 가장 큰 값 찾기
# - 시나리오2. (10배) 랜덤 배열 크기 10,000 / 랜덤 범위 50,000 의 배열을 만들어 가장 큰 값 찾기
#
# 이하 첨부파일

# %% [markdown]
# ## 영화 추천 서비스 PJT 08
# ### 비동기 통신을 이용한 웹 사이트 구현 17 left
