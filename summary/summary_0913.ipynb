# %% [markdown]
# # Django 1 Intro & Design Pattern

# %% [markdown]
# ## Web Application

# %% [markdown]
# Web appplication = web service 개발
# - =인터넷을 통해 제공되는 소프트웨어 프로그램을 구축하는 과정
# - -> 다양한 디바이스 (모바일, 태블릿, pc)에서 웹 브라우저를 통해 접근, 사용할 수 있다.

# %% [markdown]
# ## Client & Server

# %% [markdown]
# 웹의 동작 방식
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Client
# 클라이언트 = `서비스`를 `요청`하는 주체
# - -> 웹 사용자의 인터넷이 연결된 장치, 웹 브라우저
#
# ### Server
# 서버 =  클라이언트의 요청에 `응답(페이지, 로직, 파일 ~~)`하는 주체
# - -> 웹 페이지, 앱을 저장하는 컴퓨터(서버 컴퓨터)

# %% [markdown]
# 우리가 웹 페이지를 보는 과정.
# 1. 웹 브라우저(클라이언트)에서 `google.com` 입력, 엔터
# 2. 웹브라우저가 전세계 어딘가에 있는 구글 컴퓨터(서버)에 `메인 홈페이지.html`을 request
# 3. 요청 받은 구글 컴퓨터 : `메인 홈페이지.html` 파일을 찾아서 response
# 4. 웹브라우저 : 전달받은 `메인 홈페이지.html` 파일을 사람이 볼 수 있도록 해석. 사용자가 볼 수 있게 해줌

# %% [markdown]
# ## Frontend & Backend

# %% [markdown]
# - Frontend (프론트엔드) : 클라이언트
#     - 사용자 인터페이스(UI) 구성. 사용자가 애플리케이션과 상호작용할 수 있도록 함
#     - -> HTML, CSS, JavaScript, 프론트엔드 프레임워크 등~
#
# - `Backend (백엔드)` : 서버
#     - 서버에서 동작. 클라이언트의 요청에 따라 `데이터베이스` 와 상호작용 담당
#     - -> 서버 언어(python, java ~~), 백엔드 프레임워크, 데이터베이스, API, 보안 등
#
# - 이번에 공부할 부분
#
# ![image.png](attachment:image.png)
#
# *프론트엔드는 없다고 생각하고* 이걸 포함하면 `풀스택`

# %% [markdown]
# ## FrameWork

# %% [markdown]
# 웹 개발에 필요한 것.
# `= 거인의 어깨 위에서 코딩하기`
# - 개발에 필요한 다양한 기술 ex) 로그인/아웃, 회원관리, 데이터베이스, 보안 등
# - -> 모든 기능을 직접 개발하기에는 현실적으로 어려움
# - -> 잘 만들어진 도구를 효과적으로 활용하자 : 현대 웹 개발의 핵심

# %% [markdown]
# ### `Web` Framework
# - 웹 애플리케이션을 빠르게 개발할 수 있도록 도와주는 도구
# - =개발에 필요한 기본 구조, 규칙, 라이브러리 등을 제공
# - 다양한 종류가 있다.

# %% [markdown]
# ## Django

# %% [markdown]
# ### 장고 : python 기반 웹 프레임워크
#
# why??(공식 문서 맨 앞에 있음)
# - 다양성
#     - python 기반으로 웹,모바일 앱 백엔드, API 서버 및 빅데이터 관리 등 광범위한 서비스 개발에 적합
# - 확장성
#     - 대량의 데이터에 대해 빠르고 유연하게 확장할 수 있는 기능을 제공
# - 보안
#     - 취약점으로부터 보호하는 보안 기능이 기본적으로 내장되어 있음
# - 커뮤니티 지원
#     - 개발자를 위한 지원, 문서 및 업데이트를 제공하는 활성화 된 커뮤니티
#
# `검증된` 웹 프레임워크
# - `대규모 트래픽` 서비스에도 안정적인 서비스 제공 ex) 스포티파이, 인스타그램, 드랍박스, 딜리버리 히어로
#
# 앞으로.
# 장고를 사용해서 서버를 구현할 것.
#
# 가장 인기 있는 백엔드 프레임워크
# 1. Express.js (Node.js)
# 2. Django (Python)
# 3. Spring Boot (Java)
# 4. Laravel (PHP)
# 5. ASP.NET Core (C#)

# %% [markdown]
# ## `가상 환경(중요)`

# %% [markdown]
# Python 애플리케이션과 그에 따른 패키지들을 격리하여 관리할 수 있는 `독립적인 실행 환경`
# - 기존의 환경 : pip install ~~ = 전역 global
#
# why?
# - case 1.
#     - 한 개발자가 2개의 프로젝트를 진행해야 함
#     - 각각 A, B 패키지가 필요할 때, 한 번에 하나씩만 컴퓨터에 설치할 수 있음
#     - 이럴 때 독립적인 개발 환경을 위해 가상 환경을 사용
#
# - case 2.
#     - 이번에도 2개의 프로젝트를 진행함
#     - water, fire 패키지를 사용하는데, 두개를 동시에 설치하면 충돌이 발생.
#     - 충돌을 피하기 위해서 각각 독립적인 개발 필요
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 가상환경 만들기

# %% [markdown]
# #### 1. 가상 환경 venv 생성
#
# ```py
# $ python -m venv venv
# ```
# -> `venv 폴더 생성`
#
# python -m venv : 가상환경 만들겠다
#
# venv(뒤) : 가상환경 이름 -> 왜 이름이 이거임? 관례적으로 쓰는 것
# **venv 폴더 안의 내용 절대 수정 x**
#
# #### 가상 환경은 `on/off` 의 개념 in/out 아님.

# %% [markdown]
# #### 2. 가상 환경 활성화
# ```py
# $ source venv/Scripts/activate
# ```
# -> `(venv) 출력`
# -> (venv) 표시가 있다면. 가상 환경이 켜진 상태
#
# venv/Scripts/activate : 경로
# 가상은 경로에 의해서 결정됨
# -> 같은 venv 파일을 만들 수 있음 -> 그럼 구분 어떻게 함?
# -> `경로`로 하면됨
# -> 복잡해지니까 프로젝트와 함께(동일한 위치에) venv를 만들면 편하다.

# %% [markdown]
# #### 3. 환경에 설치된 패키지 목록 확인
# ```py
# $ pip list
# ```
#
# 가상 환경 활성화 하면 기존에 설치했던 pip들은 보이지 않게됨.

# %% [markdown]
# #### 4. 설치된 패키지 목록 생성
# ```py
# $ pip freeze > requirement.txt
# ```
#
# pip freeze : pip 목록을 출력 하겠다.
#
# `> requirements.txt` : 출력한 목록을 텍스트 파일에 적겠다.
#
# 이걸 왜 만드는가?
# - case
#     - A, B 협업
#     - A가 먼저 가상 환경 만들고 github에 push
#     - B가 clone을 해도 실행이 안됨
#     - 프로젝트 안에 venv가 없음. 어떤 가상환경인지 알 수가 없음
#     - -> `가상환경에 대한 정보 = 패키지 목록` 이 필요
#
# venv를 채로 push하면 되는게 아닌가?
# - pip를 몇개 설치하다보면 용량이 엄청나게 커짐.
# - -> 설치한 목록만 알려주면 용량 절약 가능.
# - 설치 코드
# ```py
# $ pip install -r requirements.txt
# ```
#
# +의존성 패키지
# - 패키지를 설치하면 단순히 하나만 설치 되는 것이 아님
# - 연관된 패키지가 전부 설치됨
# -> 한 패키키지가 다른 패키지의 기능과 코드를 사용하기 때문에 그 패키지가 존재해야만 제대로 작동
# -> 사용하려는 패키지가 설치되지 않았거나, 버전이 호환되지 않으면 오류발생, 이상한 작동함

# %% [markdown]
# #### 5. 가상 환경 끄기
#
# ```py
# $ deactivate
# ```
# 그냥 터미널을 꺼도 꺼지긴 한데 혹시나~ 하는 마음에

# %% [markdown]
# 요약.
# 1. 가상환경은 `on/off`.임 `(in/out x)`
#     - 활성화 하면 현재 터미널에만 영향을 줌
#     - 새 창 열면 다시 활성화 해야함
# 2. `방`에 들어간다고 생각하지말고 `도구 세트` 라고 생각할 것.
# 3. 프로젝트마다 별도로 설정할 것
# 4. 프로젝트와 동일한 위치에 venv 폴더를 만들 것
# 5. 가상환경 폴더는 gitignore 에 들어있음. -> 레포지토리에 안올라감
#     - 저장소 크기 줄이고 효율적인 협업, 배포를 위해서 requirements.txt파일만 공유
#
# venv, requirements는 관례적인 것이니 수정하지 말 것.
#
# -> 가상환경 & 의존선 패키지 관리를 잘 하자.

# %% [markdown]
# ## Django Project

# %% [markdown]
# 1. 가상 환경 만들기
#
# 2. 가상환경 활성화
#
# 3. 장고 설치
# ```py
# $ pip install django
# ```
#
# 4. 프로젝트 생성
# ```py
# $ django-admin startproject firstpjt .
# ```
# `django-admin`: 얘만 장고로 시작하는 명령어. 이때는 매니지 파일이 없어서.<br>
# `startproject`: 프로젝트를 시작하겠다.<br>
# `firstpjt`: 프로젝트 이름<br>
# `.`: 현재 폴더<br> 안찍어도 만들어지긴 하는데 현재 폴더가 아니고 한 겹 더 씌워서 만듦<br>
# 맨 뒤에 `.` 주의
#
# 5. 서버 실행
# ```py
# $ python manage.py runserver
# ```
# `python manage.py`: 고정
# `runserver`: 서버를 실행 하겠다.<br>
# 빨간 글자는 당분간 무시해도 됨.
#
# `+`서버를 끄고 싶으면.
# `ctrl` + `c`
#
# 터미널만 끄면 안꺼지는 경우가 많으니 주의

# %% [markdown]
# ## Django Design Pattern

# %% [markdown]
# 디자인 패턴
# - 소프트웨어 설계에서 발생하는 문제를 해결하기 위한 일반적인 해결책
# - -> 공통적인 문제를 해결하는 데 쓰이는 `형식화 된 관행`
#
# -> `애플리케이션의 구조는 이렇게 구성하자` 라는 관행(약속)
#
# MVC 디자인 패턴
# - Model, View, Controller
# - 애플리케이션을 구조화하는 대표적인 패턴
# - 데이터(M), 사용자 인터페이스(V), 비즈니스 로직(C):(M, V왔다갔다 하는거) 로 분리
#
# MTV 디자인 패턴
# - Model, Template(View의 역할), View(Controller의 역할)
# - Django가 애플리케이션을 구조화하는 패턴
# - 기존 MVC 패턴과 동일. 단순히 명칭을 다르게 함(파이썬에서는 ARR를 LIST로 쓰는 것처럼)

# %% [markdown]
# ## Project & App

# %% [markdown]
# 프로젝트 : 전체적인 설정
#
# 앱 : `하나`의 기능. 여러개는 유지보수가 어려워서 권장 x

# %% [markdown]
# Django project
# - 애플리케이션의 집합(DB 설정, URL 연결, 전체 앱 설정 등 처리)
#
# Django application
# - 독립적으로 작동하는 `기능 단위 모듈`
# - 각자 특정 기능 담당. 모여서 하나의 프로젝트 구성
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 앱을 사용 하려면.
# 1. 앱 생성 -> 무조건 생성 후에 등록할 것.!
# 앱의 이름은 `복수형`으로 지정하는 것을 권장
# ```py
# $ python manage.py startapp articles
# ```
# * 만들면 프로젝트 안에 생기는게 아니고 별도의 폴더로 만들어짐.
# - -> 앱의 존재를 프로젝트는 알 수가 없다.
#
# 2. 앱 등록(생성만 하면 프로젝트는 앱의 존재를 모름)
# 3. project -> settings -> INSTALLED_APPS =[list(내장 앱)]<br>
# list 안에 앱을 추가. (맨 위에 하는게 좋음) : 앱 구동을 위에서 아래로 하는데, 순서가 꼬여서 오류가 발생할 수 있음.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 프로젝트 구조. (나머지는 건들지 말자. )
# - `settings.py`
#     - 프로젝트의 모든 설정 관리.
#     - 자주 들어옴
#
# - `urls.py`
#     - 요청 들어오는 url에 따라 이에 해당하는 적절한 view에 연결
#     - 자주 들어옴
#
# - 건들면 안되는거.
#
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 앱 구조
# - admin.py
#     - 관리자용 페이지 설정
#
# - `model.py`
#     - DB와 관련된 Model을 정의
#     - MTV에서 M
#
# - `views.py` : 로직 = 컨트롤러, 가장 `중요`하고 바쁨.
#     - HTTP 요청을 처리하고 해당 요청에 대한 `응답`을 반환
#     - MTV에서 V
#
# - 건들면 안되는거.
#
# ![image.png](attachment:image.png)
#
# ### **M`T(templates)`V 는 어딨는가?**
# - 기본적으로 장고는 백엔드 프레임워크라서 만들어주진 않음.

# %% [markdown]
# ## Request & Response

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ### 우리가 할 흐름.
# - 요청 -> urls.py -> (views.py <- templates) -> 응답
# - 순서를 지켜야 오류를 고치는데 용의.

# %% [markdown]
# #### 1. URLs
#
# ![image.png](attachment:image.png)
#
# - path('path/', app.views.funct) 는 http://127.0.0.1:8000/path/로 접속했을 때 app.views.funct 로부터 반환받은 페이지를 url에 등록해주는 함수
# - app.view.funct 는 view함수를 불러온다는 말인 듯 하다. `프로젝트에 없고 앱에 있다 !`
# - -> 반드시 앱에서 views를 import 할 것
#
#
# ![image-2.png](attachment:image-2.png)
#
# http://127.0.0.1:8000/index/ 에 요청이 왔을 때
# request 객체를 views 모듈의 index view 함수에 전달하여 호출
# - index에는 ()를 붙이지 않는다.
# - why? 실행되었을 때 바로 작동하면 안되고, request가 있을 때에만 작동하게 하려고.

# %% [markdown]
# #### 2. View
#
# ![image.png](attachment:image.png)
#
# View 함수가 정의되는 곳.
# 특정 경로에 있는 template과 request 객체를 결합해 응답 객체를 반환
# - return은 render.
# - render(요청데이터, 템플릿 이름)
# - 모든 view 함수는 request를 첫번째 인자로 요청 객체를 필수로 받는다.
# - 꼭 request로 할 필요는 없지만 약속임.

# %% [markdown]
# #### 3. Template
#
# ![image.png](attachment:image.png)
#
# - 왜 templates 로 해야되나? 장고 개발진이 그렇게 만들었음. 이유는 없다.
#
# ![image-2.png](attachment:image-2.png)
#
# - 템플릿 만들 때 왜 폴더 안에 html을 넣는가?
# - 불러올 때 안헷갈리고 편하게 가져올려고.
#
#
# - templates 까지는 약속이라서 인지를 하고 있고, 이후의 경로는 꼭 적어줘야 인지함.

# %% [markdown]
# #### 1. -> 2. -> 3.
#
# ![image.png](attachment:image.png)
#
# #### 무조건 데이터 흐름에 맞춰서 코드를 쓰자.
# URLs -> View -> Template
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## +

# %% [markdown]
# ### 가상환경 생성 루틴

# %% [markdown]
# #### 1. git이 없을 때 Django 프로젝트 생선 전 루틴
#
# ![image.png](attachment:image.png)
#
# #### 2. git이 있을 때
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 가상 환경 쓰는 이유
#
# - 의존성 관리
#     - 라이브러리 및 패키지를 각 프로젝트마다 독립적으로 사용 가능
#
# - 팀 프로젝트  협업
#     - 모든 팀원이 동일한 환경과 의존성 위에서 작업하여 버전간 충돌을 방지

# %% [markdown]
# ### Django 관련

# %% [markdown]
# #### LTS (Long-Term Support)
# - 프레임워크나 라이브러리 등의 소프트웨어에서 장기간 지원되는(버그픽스, 업데이트?) 안정적인 버전을 의미
# - 기업이나 대규모 프로젝트에서는 소프트웨어 업그레이드에 많은 비용과 시간이 필요하기 때문에 안정적이고 장기간 지원되는 버전이 필요

# %% [markdown]
# #### Django는 Full Stack framework 인가요?
# - 맞지만, 프론트엔드는 다른 프레임워크에 비해서 미흡함.
# - Backend Framework라고 도 부른다.

# %% [markdown]
# #### render()
#
# - 주어진 템플릿을 주어진 컨텍스트 데이터와 결합하고 렌더링 된 텍스트와 함께 HttpResponse 응답 객체를 반환하는 함수
#
# 1. request
#     - 응답을 생성하는 데 사용되는 요청 객체
#
# 2. template_name
#     - 템플릿 이름의 경로
#
# 3. context
#     - 템플릿에서 사용할 데이터 (딕셔너리 타입으로 작성)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### MTV 디자인 패턴 정리
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### Trailing Comma
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### `프레임워크의 규칙 및 설계 철학`
#
# 1. urls.py 에서 각 url 문자열 경로는 반드시 '/' 로 끝남
# 2. views.py 에서 모든 view 함수는 첫번째 인자로 요청 객체를 받음
#     - 매개변수 이름은 반드시 request로 지정하기
# 3. Django는 특정 경로에 있는 template 파일만 읽어올 수 있음
#     - 특정 경로: app폴더/templates/
