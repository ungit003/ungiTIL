# %% [markdown]
# # <span width = 200px style = "color:black; background-color:white">DB 01 SQL</span>

# %% [markdown]
# ## Database

# %% [markdown]
# ### 개요

# %% [markdown]
# #### 데이터베이스
# 체계적인 데이터 모음

# %% [markdown]
# #### 데이터
# 저장이나 처리에 효율적인 형태로 변환된 정보

# %% [markdown]
# #### 증가하는 데이터 사용량
# - 배달의 민족 국내 주문 건수 6억 8천만건 (2020)
# - 구독자 2억 3840만명이 1000억 시간 넷플릭스 시청 (2023 1~6월)
# - 전세계 모든 데이터의 약 90%는 2015년 이후 생산된 것 (IBM)

# %% [markdown]
# #### 데이터 센터의 성장
# - 네이버 - 제2데이터센터에 6500억 투자 (2020)
# - 카카오 - 제1데이터센터와 제2데이터센터에 1.5조 투자(2022)
# - 전 세계 데이터 센터 시장 2022년부터 2026년까지 연평균 20% 이상 성장 예상
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 데이터를 저장하고 잘 관리하여 활용할 수 있는 기술이 중요해짐
# - > 우리가 알고 있는 데이터 저장 방식은 어떤 것이 있을까?

# %% [markdown]
# #### 기존의 데이터 저장 방식
# 1. 파일(File) 이용
# 2. 스프레드 시트(Spreadsheet) 이용

# %% [markdown]
# ##### 1. 파일을 이용한 데이터 관리
# - 어디에서나 쉽게 사용 가능
# - 데이터를 구조적으로 관리하기 어려움
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### 2. 스프레드 시트를 이용한 데이터 관리
# - 테이블의 열과 행을 사용해 데이터를 구조적으로 관리 가능
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### 스프레드 시트의 한계
# - 크기
#     - 일반적으로 약 100만 행까지만 저장가능
# - 보안
#     - 단순히 파일이나 링크 소유 여부에 따른 단순한 접근 권한 기능 제공
# - 정확성
#     - 만약 공식적으로 `강원`의 지명이 `강언`으로 바뀌었다고 가정하면?
#     - 이 변경으로 인해 테이블 모든 위치에서 해당 값을 업데이트 해야 함
#     - 찾기 및 바꾸기 기능을 사용해 바꿀 수 있지만 만약 데이터가 여러 시트에 분산되어 있다면 변경에 누락이 생기거나 추가 문제가 발생할 수 있음

# %% [markdown]
# #### 데이터베이스 역할
# 데이터를 저장하고 조작 : CRUD

# %% [markdown]
# ## Relational Database

# %% [markdown]
# ### 개요

# %% [markdown]
# #### 데이터베이스 역할
# 데이터를 저장(구조적 저장)하고 조작(CRUD)

# %% [markdown]
# #### 관계형 데이터베이스
# 데이터 간에 관계가 있는 데이터 항목들의 모음
# - 테이블, 행, 열의 정보를 구조화 하는 방식
# - 서로 관련된 데이터 포인터를 저장하고 이에 대한 엑세스를 제공
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 관계
# 여러 테이블 간의 (논리적) 연결

# %% [markdown]
# ##### 관계로 할 수 있는 것
# - 이 관계로 인해 두 테이블을 사용하여 데이터를 다양한 형식으로 조회할 수 있음
#     - 특정 날짜에 구매한 모든 고객 조회
#     - 지난 달에 배송일이 지연된 고객 조회 등

# %% [markdown]
# #### 관계형 데이터베이스 예시
# - 다음과 같이 고객 데이터가 테이블에 저장되어 있다고 가정
# - 고객 데이터 간 비교를 위해서는 어떤 값을 활용해야 할까?
#   - > 이름? 주소? 만약 동명이인이나 같은 주소지가 있다면?
#
# ![image.png](attachment:image.png)
#
# - 다음과 같이 고객 데이터가 테이블에 저장되어 있다고 가정
# - 고객 데이터 간 비교를 위해서는  어떤 값을 활용해야 할까?
#   - > 각 데이터에 고유한 식별 값을 부여하기 (기본 키, Primary Key)
#
# ![image-2.png](attachment:image-2.png)
#
# - 다음과 같이 각 고객이 주문한 주문데이터가 테이블에 저장되어 있다고 가정
# - 누가 어떤 주문을 했는 지 어떻게 식별할 수 있을까?
#     - > 고객 이름> 마찬가지로 동명이인이 있다면?
#
# ![image-3.png](attachment:image-3.png)
#
# - 다음과 같이 각 고객이 주문한 주문데이터가 테이블에 저장되어 있다고 가정
# - 누가 어떤 주문을 했는지 어떻게 식별할 수 있을까?
#     - > 주문 정보에 고객의 고유한 식별 값을 저장하기 (외래 키, Foreign Key)
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# #### 관계형 데이터베이스 관련 키워드
# 1. Table (aka Relation)
#     - 데이터를 기록하는 곳<br>
# ![image.png](attachment:image.png)
#
# 2. Field (aka Column, Attribute)
#     - 각 필드에는 고유한 데이터 형식(타입)이 지정됨<br>
# ![image-2.png](attachment:image-2.png)
#
# 3. Record (aka Row, Tuple)
#     - 각 레코드에는 구체적인 데이터 값이 저장됨<br>
# ![image-3.png](attachment:image-3.png)
#
# 4. Database (aka Schema)
#     - 테이블의 집합<br>
# ![image-4.png](attachment:image-4.png)
#
# 5. Primary Key (기본 키, PK)
#     - 각 레코드의 고유한 값
#     - 관계형 데이터베이스에서 `레코드 식별자`로 활용<br>
# ![image-5.png](attachment:image-5.png)
#
# 6. Foreign Key (외래 키, FK)
#     - 테이블의 필드 중 다른 테이블의 레코드를 식별할 수 있는 키
#     - 다른 테이블의 기본 키를 참조
#     - 각 레코드에서 서로 다른 테이블 간의 `관계를 만드는 데` 사용<br>
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# ## RDBMS

# %% [markdown]
# ### DBMS
# Database Management System : 데이터베이스를 관리하는 소프트웨어 프로그램
# - 데이터 저장 및 관리를 용이하게 하는 시스템
# - 데이터베이스와 사용자 간의 인터페이스 역할
# - 사용자가 데이터 구성, 업데이트, 모니터링, 백업, 복구 등을 할 수 있도록 도움

# %% [markdown]
# ### RDBMS
# Relational Database Mangement System : 관계형 데이터베이스를 관리하는 소프트웨어 프로그램

# %% [markdown]
# #### RDMBS 서비스 종류
# - SQLite
# - MySQL
# - PostgreSQL
# - Oracle Database
# - ~~~

# %% [markdown]
# ##### SQLite
# 경량의 오픈 소스 데이터베이스 관리 시스템
# - > 컴퓨터나 모바일 기기에 내장되어 간단하고 효율적인 데이터 저장 및 관리를 제공

# %% [markdown]
# ### 데이터베이스 정리
# - Table은 데이터가 기록되는 곳
# - Table에는 행에서 고유하게 식별 가능한 기본 키 라는 속성이 있으며 외래 키를 사용하여 각 행에서 서로 다른 테이블 간의 관계를 만들 수 있음
# - 데이터는 기본 키 또는 외래 키를 통해 결합(join)될 수 있는 여러 테이블을 걸쳐 구조화 됨

# %% [markdown]
# ## SQL

# %% [markdown]
# ### 개요

# %% [markdown]
# #### SQL
# Structure Query Language : 테이블 형태로 `구조화`된 관계형 데이터베이스에게 요청을 `질의(요청)`
#
# 데이터베이스에 정보를 저장하고 처리하기 위한 프로그래밍 언어
#
# - 관계형 데이터베이스와의 대화를 위해 사용하는 프로그래밍 언어
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### SQL Syntax
# ![image.png](attachment:image.png)
#
# 1. SQL 키워드는 대소문자를 구분하지 않음
#     - 하지만 `대문자`로 작성하는 것을 권장 (명시적 구분)
#
# 2. 각 SQL Statements의 끝에는 `세미콜론(';')이 필요
#     - 세미콜론은 각 SQL Statements을 구분하는 방법 (명령어의 마침표)

# %% [markdown]
# ### SQL Statements

# %% [markdown]
# #### SQL Statements
# SQL을 구성하는 가장 기본적인 코드 블록

# %% [markdown]
# #### SQL Statements 예시
# ![image.png](attachment:image.png)
#
# - 해당 예시 코드는 SELECT Statements라 부름
# - 이 Statement는 **SELECT, FROM** 2개의 keyword로 구성됨

# %% [markdown]
# #### 수행 목적에 따른 SQL Statements 4가지 유형
# 1. DDL - 데이터 정의
# 2. DQL - 데이터 검색
# 3. DML - 데이터 조작
# 4. DCL - 데이터 제어
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### SQL 학습
# - 단순히 SQL 문법을 암기하고 상황에 따라 실행하는 것이 아닌 SQL을 통해 관계형 데이터베이스를 잘 이해하고 다루는 방법을 학습

# %% [markdown]
# ## 참고

# %% [markdown]
# ### Query
# - '데이터베이스로부터 정보를 요청' 하는 것
# - 일반적으로 SQL로 작성하는 코드를 쿼리문(SQL문)이라 함

# %% [markdown]
# ### SQL 표준
# - SQL은 미국 국립 표준 협회(ANSI)와 국제 표준화 기구(ISO)에 의해 표준이 채택됨
# - 모든 RDBMS에서 SQL 표준을 지원
# - 다만 각 RDBMS마다 독자적인 기능에 따라 표준을 벗어나늠 문법이 존재하니 주의

# %% [markdown]
# # Single Table Queries

# %% [markdown]
# ## SQL Statements 유형
# - 검색하는게 제일 중요 !
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Querying data

# %% [markdown]
# ### SELECT

# %% [markdown]
# #### `SELECT` statement
# 테이블에서 데이터를 조회

# %% [markdown]
# #### SELECT syntax
# ![image.png](attachment:image.png)
#
# - SELECT 키워드 이후 데이터를 선택하려는 필드를 하나 이상 지정
# - FROM 키워드 이후 데이터를 선택하려는 테이블의 이름을 지정

# %% [markdown]
# ##### SELECT 활용 1
# 테이블 employees에서 LastName 필드의 모든 데이터를 조회
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ##### SELECT 활용 2
# 테이블 employees에서 LastName, FirstName 필드의 모든 데이터를 조회

# %% [markdown]
# ##### SELECT 활용 3

# %% [markdown]
# ##### SELECT 활용 4

# %% [markdown]
# ##### SELECT 활용 5

# %% [markdown]
# #### SELECT 정리
# - 테이블의 데이터를 조회 및 반환
# - `*` (asterisk)를 사용하여 모든 필드 선택

# %% [markdown]
# ## Sorting data

# %% [markdown]
# ### ORDER BY

# %% [markdown]
# #### `ORDER BY` statement
# 조회 결과의 레코드를 정렬

# %% [markdown]
# #### ORDER BY syntax
# ![image.png](attachment:image.png)
#
# - FROM clause(절) 뒤에 위치
# - 하나 이상의 컬럼을 기준으로 결과를 오름차순(ASC, 기본 값), 내림차순 (DESC)으로 정렬

# %% [markdown]
# ##### ORDER BY 활용 1

# %% [markdown]
# ##### ORDER BY 활용 2

# %% [markdown]
# ##### ORDER BY 활용 3

# %% [markdown]
# ##### ORDER BY 활용 4

# %% [markdown]
# #### 정렬에서의 NULL
# NULL 값이 존재할 경우 오름차순 정렬 시 결과에 NULL이 먼저 출력
# ![image.png](attachment:image.png)

# %% [markdown]
# #### SELECT statement 실행 순서
# ![image.png](attachment:image.png)
#
# 1. 테이블에서 2. 조회하여 3. 정렬

# %% [markdown]
# ## Filtering data

# %% [markdown]
# ### Filtering data 관련 Keywords
# - Clause
#     - DISTINCT
#     - WHERE
#     - LIMIT
# - Operator
#     - BETWEEN
#     - IN
#     - LIKE
#     - Comparison
#     - Logical

# %% [markdown]
# ### DISTINCT

# %% [markdown]
# #### `DISTINCT` statement
# 조회 결과에서 중복된 레코드를 제거

# %% [markdown]
# #### DISTINCT syntax
# ![image.png](attachment:image.png)
#
# - SELECT 키워드 바로 뒤에 작성해야 함
# - SELECT DISTINCT 키워드 다음에 고유한 값을 선택하려는 하나 이상의 필드를 지정

# %% [markdown]
# ##### DISTNCT 활용 1

# %% [markdown]
# ##### DISTNCT 활용 1

# %% [markdown]
# ### WHERE

# %% [markdown]
# #### `WHERE` statement
# 조회 시 특정 검색 조건을 지정

# %% [markdown]
# #### WHERE syntax
# ![image.png](attachment:image.png)
#
# - From clause 뒤에 위치
# - search_condition은 비교연산자 및 논리연산자(AND, OR, NOT 등)를 사용하는 구문이 사용됨

# %% [markdown]
# ##### WHERE 활용 1

# %% [markdown]
# ##### WHERE 활용 2

# %% [markdown]
# ##### WHERE 활용 3

# %% [markdown]
# ##### WHERE 활용 4

# %% [markdown]
# ##### WHERE 활용 5

# %% [markdown]
# ##### WHERE 활용 6

# %% [markdown]
# ##### WHERE 활용 7

# %% [markdown]
# ##### WHERE 활용 8

# %% [markdown]
# ##### WHERE 활용 9

# %% [markdown]
# ##### WHERE 활용 10

# %% [markdown]
# ### Operators

# %% [markdown]
# ### Comparison Operators
# 비교 연산자
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Logical Operators
# 논리 연산자
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### `IN` Operator
# 값이 특정 목록 안에 있는지 확인

# %% [markdown]
# ### `LIKE` Operator
# 값이 특정 패턴에 일치하는지 확인(Wildcard와 함께 사용)

# %% [markdown]
# #### Wildcard Characters
# ![image.png](attachment:image.png)

# %% [markdown]
# ### LIMIT

# %% [markdown]
# #### `LIMIT` clause
# 조회하는 레코드 수를 제한

# %% [markdown]
# #### LIMIT syntax
# ![image.png](attachment:image.png)
#
# - 하나 또는 두 개의 인자를 사용 (0 또는 양의 정수)
# - row_count는 조회하는 최대 레코드 수를 지정

# %% [markdown]
# #### LIMIT & OFFSET 예시
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### LIMIT 활용 1

# %% [markdown]
# ##### LIMIT 활용 2

# %% [markdown]
# ## Grouping data

# %% [markdown]
# ### GROUP BY

# %% [markdown]
# #### `GROUP BY` clause
# 레코드를 그룹화하여 요약본 생성 (`집계 함수`와 함께 사용)

# %% [markdown]
# ##### Aggregation Functions
# 집계 함수 : 값에 대한 계산을 수행하고 단일한 값을 반환하는 함수
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### GROUP BY syntax
# ![image.png](attachment:image.png)
#
# - FROM 및 WHERE 절 뒤에 배치
# - GROUP BY 절 뒤에 그룹화 할 필드 목록을 작성

# %% [markdown]
# #### GROUP BY 예시
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ##### GROUP BY 활용 1

# %% [markdown]
# ##### GROUP BY 활용 2

# %% [markdown]
# #### SELECT statement 실행 순서
# ![image.png](attachment:image.png)
#
# 1. 테이블에서 2. 특정 조건에 맞추어 3. 그룹화 하고 4. 만약 그룹 중에서 조건이 있다면 맞추고 5. 조회하여 6. 정렬하고 7. 특정 위치의 값을 가져옴

# %% [markdown]
# # Managing Tables

# %% [markdown]
# ## Greate a table

# %% [markdown]
# # Modifying Data

# %% [markdown]
# ## Insert data

# %% [markdown]
# ### INSERT

# %% [markdown]
# ## Update data

# %% [markdown]
# ### UPDATE

# %% [markdown]
# ## Delete data

# %% [markdown]
# ### DELETE

# %% [markdown]
# ## 참고
